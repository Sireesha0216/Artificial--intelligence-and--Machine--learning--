# %% [markdown]
# <a href="https://colab.research.google.com/github/Sireesha0216/Artificial--intelligence-and--Machine--learning--/blob/main/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Task-1 The downloaded set

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/school_scores-1 (1) (2).csv')

# %%
df
# Out:
#      Year State.Code     State.Name  Total.Math  Total.Test-takers  \
# 0    2005         AL        Alabama         559               3985
# 1    2005         AK         Alaska         519               3996
# 2    2005         AZ        Arizona         530              18184
# 3    2005         AR       Arkansas         552               1600
# 4    2005         CA     California         522             186552
# ..    ...        ...            ...         ...                ...
# 572  2015         VA       Virginia         517              59621
# 573  2015         WA     Washington         511              44423
# 574  2015         WV  West Virginia         500               2501
# 575  2015         WI      Wisconsin         606               2277
# 576  2015         WY        Wyoming         587                181
#
#      Total.Verbal  Academic Subjects.Arts/Music.Average GPA  \
# 0             567                                      3.92
# ...

# %%
df.head()
# Out:
#    Year State.Code  State.Name  Total.Math  Total.Test-takers  Total.Verbal  \
# 0  2005         AL     Alabama         559               3985           567
# 1  2005         AK      Alaska         519               3996           523
# 2  2005         AZ     Arizona         530              18184           526
# 3  2005         AR    Arkansas         552               1600           563
# 4  2005         CA  California         522             186552           504
#
#    Academic Subjects.Arts/Music.Average GPA  \
# 0                                      3.92
# 1                                      3.76
# 2                                      3.85
# 3                                      3.90
# 4                                      3.76
#
#    Academic Subjects.Arts/Music.Average Years  \
# 0                                         2.2
# 1                                         1.9
# 2                                         2.1
# 3                                         2.2
# ...

# %%
df.tail()
# Out:
#      Year State.Code     State.Name  Total.Math  Total.Test-takers  \
# 572  2015         VA       Virginia         517              59621
# 573  2015         WA     Washington         511              44423
# 574  2015         WV  West Virginia         500               2501
# 575  2015         WI      Wisconsin         606               2277
# 576  2015         WY        Wyoming         587                181
#
#      Total.Verbal  Academic Subjects.Arts/Music.Average GPA  \
# 572           518                                      3.83
# 573           502                                      3.83
# 574           509                                      3.92
# 575           591                                      3.93
# 576           588                                      3.91
#
#      Academic Subjects.Arts/Music.Average Years  \
# 572                                         2.1
# 573                                         2.2
# 574                                         2.4
# ...

# %%
#Task2- check the datatypes of columns

# %%
df.dtypes
# Out:
# Year                                               int64
# State.Code                                        object
# State.Name                                        object
# Total.Math                                         int64
# Total.Test-takers                                  int64
#                                                    ...
# Score Ranges.Between 700 to 800.Math.Males         int64
# Score Ranges.Between 700 to 800.Math.Total         int64
# Score Ranges.Between 700 to 800.Verbal.Females     int64
# Score Ranges.Between 700 to 800.Verbal.Males       int64
# Score Ranges.Between 700 to 800.Verbal.Total       int64
# Length: 99, dtype: object

# %%
#Task-3 Perform Descriptive Statistics

# %%
df.describe()
# Out:
#               Year  Total.Math  Total.Test-takers  Total.Verbal  \
# count   577.000000  577.000000         577.000000    577.000000
# mean   2010.019064  535.682842       27914.242634    531.334489
# std       3.169623   46.171611       45602.106878     44.318302
# min    2005.000000  383.000000         134.000000    401.000000
# 25%    2007.000000  504.000000        2536.000000    496.000000
# 50%    2010.000000  527.000000        6468.000000    522.000000
# 75%    2013.000000  571.000000       35799.000000    572.000000
# max    2015.000000  619.000000      241553.000000    612.000000
#
#        Academic Subjects.Arts/Music.Average GPA  \
# count                                577.000000
# mean                                   3.822704
# std                                    0.093249
# min                                    3.430000
# 25%                                    3.760000
# 50%                                    3.850000
# ...

# %%
#Task-4 Check for null values

# %%
CheckingNull=df.isnull().sum

# %%
CheckingNull
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of       Year  State.Code  State.Name  Total.Math  Total.Test-takers  \
# 0    False       False       False       False              False
# 1    False       False       False       False              False
# 2    False       False       False       False              False
# 3    False       False       False       False              False
# 4    False       False       False       False              False
# ..     ...         ...         ...         ...                ...
# 572  False       False       False       False              False
# 573  False       False       False       False              False
# 574  False       False       False       False              False
# 575  False       False       False       False              False
# 576  False       False       False       False              False
#
#      Total.Verbal  Academic Subjects.Arts/Music.Average GPA  \
# ...

# %%
#Task -5 If null values presented handle the null values and remove the unwanted columns

# %%
print("No null values-\n", CheckingNull)
# Out:
# No null values-
#  <bound method NDFrame._add_numeric_operations.<locals>.sum of       Year  State.Code  State.Name  Total.Math  Total.Test-takers  \
# 0    False       False       False       False              False
# 1    False       False       False       False              False
# 2    False       False       False       False              False
# 3    False       False       False       False              False
# 4    False       False       False       False              False
# ..     ...         ...         ...         ...                ...
# 572  False       False       False       False              False
# 573  False       False       False       False              False
# 574  False       False       False       False              False
# 575  False       False       False       False              False
# 576  False       False       False       False              False
#
#      Total.Verbal  Academic Subjects.Arts/Music.Average GPA  \
# ...
